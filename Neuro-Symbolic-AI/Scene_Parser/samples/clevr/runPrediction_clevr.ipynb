# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")


# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/clevr/"))  # To find local version
import clevr

# %matplotlib inline 


# Directory of images to run detection on
#IMAGE_DIR = os.path.join(ROOT_DIR, "datasets/clevr/")
IMAGE_DIR = '/home/raswanth/AI/Neuro-Symbolic Ai/CLEVR_v1.0/images/val' 

class InferenceConfig(clevr.ClevrConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                109
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           clevr
# NUM_CLASSES                    97
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
CLEVR_MODEL_PATH = '/home/raswanth/AI/Neuro-Symbolic Ai/Neuro-Symbolic-AI/Scene_Parser/Weights/mask_rcnn_clevr_master.h5'


# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)
# Out:
# WARNING:tensorflow:From /home/raswanth/anaconda3/envs/Rnn/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# Load weights trained on MS-COCO
model.load_weights(CLEVR_MODEL_PATH, by_name=True)

# CLEVR Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')

#class_names = ['BG', 'cube', 'sphere', 'cylinder']

# %%
shape_categories = {'cube': 1,
                            'sphere': 2,
                            'cylinder': 3}
material_categories = {'rubber': 1,
                               'metal': 2}
color_categories = {'gray': 1,
                            'blue': 2,
                            'brown': 3,
                            'yellow': 4,
                            'red': 5,
                            'green': 6,
                            'purple': 7,
                            'cyan': 8}
size_categories = {'small': 1,
                           'large': 2}
class_names = ['BG']
for shape in shape_categories:
    for mat in material_categories:
        for col in color_categories:
            for size in size_categories:
                class_name = shape + " " + mat + " " + col + " " + size
                class_names.append(class_name)

# %%
# Load a random image from the images folder
file_names = next(os.walk(IMAGE_DIR))[2]

# %%
file_names
# Out:
# ['CLEVR_val_000462.png',
#  'CLEVR_val_007847.png',
#  'CLEVR_val_000566.png',
#  'CLEVR_val_013390.png',
#  'CLEVR_val_012000.png',
#  'CLEVR_val_001766.png',
#  'CLEVR_val_001230.png',
#  'CLEVR_val_001042.png',
#  'CLEVR_val_013520.png',
#  'CLEVR_val_009360.png',
#  'CLEVR_val_011818.png',
#  'CLEVR_val_013161.png',
#  'CLEVR_val_006188.png',
#  'CLEVR_val_011939.png',
#  'CLEVR_val_006539.png',
#  'CLEVR_val_011677.png',
#  'CLEVR_val_005868.png',
#  'CLEVR_val_005973.png',
#  'CLEVR_val_007469.png',
#  'CLEVR_val_014790.png',
#  'CLEVR_val_000029.png',
#  'CLEVR_val_012329.png',
#  'CLEVR_val_003673.png',
#  'CLEVR_val_013213.png',
#  'CLEVR_val_009597.png',
#  'CLEVR_val_011059.png',
#  'CLEVR_val_012693.png',
#  'CLEVR_val_002979.png',
#  'CLEVR_val_012108.png',
#  'CLEVR_val_006831.png',
#  'CLEVR_val_003456.png',
#  'CLEVR_val_005517.png',
#  'CLEVR_val_013450.png',
#  'CLEVR_val_008890.png',
#  'CLEVR_val_014548.png',
#  'CLEVR_val_001859.png',
#  'CLEVR_val_010337.png',
#  'CLEVR_val_011825.png',
#  'CLEVR_val_009627.png',
#  'CLEVR_val_013122.png',
#  'CLEVR_val_008176.png',
#  'CLEVR_val_001602.png',
#  'CLEVR_val_013484.png',
#  'CLEVR_val_004426.png',
#  'CLEVR_val_013660.png',
#  'CLEVR_val_001863.png',
#  'CLEVR_val_003034.png',
#  'CLEVR_val_001557.png',
#  'CLEVR_val_003196.png',
#  'CLEVR_val_006066.png',
#  'CLEVR_val_013303.png',
#  'CLEVR_val_000948.png',
#  'CLEVR_val_014867.png',
#  'CLEVR_val_010853.png',
#  'CLEVR_val_010556.png',
#  'CLEVR_val_003106.png',
#  'CLEVR_val_008791.png',
#  'CLEVR_val_001235.png',
#  'CLEVR_val_002727.png',
#  'CLEVR_val_013209.png',
#  'CLEVR_val_003256.png',
#  'CLEVR_val_006267.png',
#  'CLEVR_val_010827.png',
#  'CLEVR_val_004405.png',
#  'CLEVR_val_004320.png',
#  'CLEVR_val_007765.png',
#  'CLEVR_val_004639.png',
#  'CLEVR_val_012527.png',
#  'CLEVR_val_006477.png',
#  'CLEVR_val_009659.png',
#  'CLEVR_val_014065.png',
#  'CLEVR_val_008557.png',
#  'CLEVR_val_000125.png',
#  'CLEVR_val_013561.png',
#  'CLEVR_val_009836.png',
#  'CLEVR_val_000943.png',
#  'CLEVR_val_009417.png',
#  'CLEVR_val_002234.png',
#  'CLEVR_val_010599.png',
#  'CLEVR_val_005812.png',
#  'CLEVR_val_000665.png',
#  'CLEVR_val_000410.png',
#  'CLEVR_val_007257.png',
#  'CLEVR_val_000138.png',
#  'CLEVR_val_012439.png',
#  'CLEVR_val_013765.png',
#  'CLEVR_val_010675.png',
#  'CLEVR_val_014218.png',
#  'CLEVR_val_001849.png',
#  'CLEVR_val_000332.png',
#  'CLEVR_val_003676.png',
#  'CLEVR_val_014490.png',
#  'CLEVR_val_009719.png',
#  'CLEVR_val_011726.png',
#  'CLEVR_val_004408.png',
#  'CLEVR_val_011881.png',
#  'CLEVR_val_008466.png',
#  'CLEVR_val_003067.png',
#  'CLEVR_val_001287.png',
#  'CLEVR_val_000682.png',
#  'CLEVR_val_003183.png',
#  'CLEVR_val_002927.png',
#  'CLEVR_val_014998.png',
#  'CLEVR_val_005701.png',
#  'CLEVR_val_003504.png',
#  'CLEVR_val_004429.png',
#  'CLEVR_val_000359.png',
#  'CLEVR_val_014431.png',
#  'CLEVR_val_003239.png',
#  'CLEVR_val_012937.png',
#  'CLEVR_val_014499.png',
#  'CLEVR_val_012896.png',
#  'CLEVR_val_000835.png',
#  'CLEVR_val_003284.png',
#  'CLEVR_val_003090.png',
#  'CLEVR_val_011795.png',
#  'CLEVR_val_000304.png',
#  'CLEVR_val_008754.png',
#  'CLEVR_val_005419.png',
#  'CLEVR_val_008749.png',
#  'CLEVR_val_009053.png',
#  'CLEVR_val_014382.png',
#  'CLEVR_val_013242.png',
#  'CLEVR_val_014770.png',
#  'CLEVR_val_012316.png',
#  'CLEVR_val_009040.png',
#  'CLEVR_val_004480.png',
#  'CLEVR_val_012742.png',
#  'CLEVR_val_003463.png',
#  'CLEVR_val_008635.png',
#  'CLEVR_val_000811.png',
#  'CLEVR_val_005882.png',
#  'CLEVR_val_007000.png',
#  'CLEVR_val_008709.png',
#  'CLEVR_val_007596.png',
#  'CLEVR_val_003603.png',
#  'CLEVR_val_004904.png',
#  'CLEVR_val_007657.png',
#  'CLEVR_val_011207.png',
#  'CLEVR_val_014922.png',
#  'CLEVR_val_002868.png',
#  'CLEVR_val_003483.png',
#  'CLEVR_val_010392.png',
#  'CLEVR_val_003005.png',
#  'CLEVR_val_007760.png',
#  'CLEVR_val_014962.png',
#  'CLEVR_val_000367.png',
#  'CLEVR_val_009082.png',
#  'CLEVR_val_014610.png',
#  'CLEVR_val_009117.png',
#  'CLEVR_val_009509.png',
#  'CLEVR_val_003296.png',
#  'CLEVR_val_002592.png',
#  'CLEVR_val_006347.png',
#  'CLEVR_val_010099.png',
#  'CLEVR_val_002064.png',
#  'CLEVR_val_003155.png',
#  'CLEVR_val_001414.png',
#  'CLEVR_val_000611.png',
#  'CLEVR_val_001960.png',
#  'CLEVR_val_000141.png',
#  'CLEVR_val_014685.png',
#  'CLEVR_val_013859.png',
#  'CLEVR_val_003065.png',
#  'CLEVR_val_000170.png',
#  'CLEVR_val_002826.png',
#  'CLEVR_val_011485.png',
#  'CLEVR_val_002224.png',
#  'CLEVR_val_008732.png',
#  'CLEVR_val_004036.png',
#  'CLEVR_val_011469.png',
#  'CLEVR_val_008571.png',
#  'CLEVR_val_000684.png',
#  'CLEVR_val_008180.png',
#  'CLEVR_val_014994.png',
#  'CLEVR_val_011452.png',
#  'CLEVR_val_005016.png',
#  'CLEVR_val_000275.png',
#  'CLEVR_val_006746.png',
#  'CLEVR_val_001665.png',
#  'CLEVR_val_013280.png',
#  'CLEVR_val_000695.png',
#  'CLEVR_val_008379.png',
#  'CLEVR_val_013828.png',
#  'CLEVR_val_012866.png',
#  'CLEVR_val_014348.png',
#  'CLEVR_val_002301.png',
#  'CLEVR_val_010145.png',
#  'CLEVR_val_002017.png',
#  'CLEVR_val_007206.png',
#  'CLEVR_val_005726.png',
#  'CLEVR_val_002978.png',
#  'CLEVR_val_003782.png',
#  'CLEVR_val_012552.png',
#  'CLEVR_val_007666.png',
#  'CLEVR_val_002352.png',
#  'CLEVR_val_009969.png',
#  'CLEVR_val_008389.png',
#  'CLEVR_val_002514.png',
#  'CLEVR_val_003511.png',
#  'CLEVR_val_001346.png',
#  'CLEVR_val_010281.png',
#  'CLEVR_val_013170.png',
#  'CLEVR_val_013093.png',
#  'CLEVR_val_002065.png',
#  'CLEVR_val_004999.png',
#  'CLEVR_val_008694.png',
#  'CLEVR_val_010615.png',
#  'CLEVR_val_011634.png',
#  'CLEVR_val_012119.png',
#  'CLEVR_val_014684.png',
#  'CLEVR_val_010238.png',
#  'CLEVR_val_009382.png',
#  'CLEVR_val_005084.png',
#  'CLEVR_val_011127.png',
#  'CLEVR_val_000614.png',
#  'CLEVR_val_010891.png',
#  'CLEVR_val_000179.png',
#  'CLEVR_val_007368.png',
#  'CLEVR_val_003629.png',
#  'CLEVR_val_001060.png',
#  'CLEVR_val_014500.png',
#  'CLEVR_val_003487.png',
#  'CLEVR_val_001071.png',
#  'CLEVR_val_000974.png',
#  'CLEVR_val_000400.png',
#  'CLEVR_val_012232.png',
#  'CLEVR_val_009508.png',
#  'CLEVR_val_004359.png',
#  'CLEVR_val_001263.png',
#  'CLEVR_val_013398.png',
#  'CLEVR_val_014745.png',
#  'CLEVR_val_003635.png',
#  'CLEVR_val_001092.png',
#  'CLEVR_val_003814.png',
#  'CLEVR_val_006618.png',
#  'CLEVR_val_001837.png',
#  'CLEVR_val_014961.png',
#  'CLEVR_val_003561.png',
#  'CLEVR_val_004626.png',
#  'CLEVR_val_008465.png',
#  'CLEVR_val_007406.png',
#  'CLEVR_val_004797.png',
#  'CLEVR_val_009217.png',
#  'CLEVR_val_004560.png',
#  'CLEVR_val_010740.png',
#  'CLEVR_val_001645.png',
#  'CLEVR_val_007731.png',
#  'CLEVR_val_004364.png',
#  'CLEVR_val_012229.png',
#  'CLEVR_val_010754.png',
#  'CLEVR_val_007601.png',
#  'CLEVR_val_003642.png',
#  'CLEVR_val_003078.png',
#  'CLEVR_val_010554.png',
#  'CLEVR_val_002661.png',
#  'CLEVR_val_005703.png',
#  'CLEVR_val_006493.png',
#  'CLEVR_val_003774.png',
#  'CLEVR_val_011721.png',
#  'CLEVR_val_014930.png',
#  'CLEVR_val_010562.png',
#  'CLEVR_val_000055.png',
#  'CLEVR_val_002449.png',
#  'CLEVR_val_000870.png',
#  'CLEVR_val_001143.png',
#  'CLEVR_val_007997.png',
#  'CLEVR_val_013097.png',
#  'CLEVR_val_004350.png',
#  'CLEVR_val_001738.png',
#  'CLEVR_val_014016.png',
#  'CLEVR_val_009006.png',
#  'CLEVR_val_002252.png',
#  'CLEVR_val_009186.png',
#  'CLEVR_val_001156.png',
#  'CLEVR_val_005711.png',
#  'CLEVR_val_004725.png',
#  'CLEVR_val_011431.png',
#  'CLEVR_val_008154.png',
#  'CLEVR_val_010095.png',
#  'CLEVR_val_000039.png',
#  'CLEVR_val_014544.png',
#  'CLEVR_val_010370.png',
#  'CLEVR_val_002532.png',
#  'CLEVR_val_010094.png',
#  'CLEVR_val_003197.png',
#  'CLEVR_val_013987.png',
#  'CLEVR_val_014872.png',
#  'CLEVR_val_004519.png',
#  'CLEVR_val_010110.png',
#  'CLEVR_val_003739.png',
#  'CLEVR_val_004954.png',
#  'CLEVR_val_007635.png',
#  'CLEVR_val_005761.png',
#  'CLEVR_val_002270.png',
#  'CLEVR_val_000328.png',
#  'CLEVR_val_001915.png',
#  'CLEVR_val_000143.png',
#  'CLEVR_val_014848.png',
#  'CLEVR_val_004752.png',
#  'CLEVR_val_013184.png',
#  'CLEVR_val_009485.png',
#  'CLEVR_val_011301.png',
#  'CLEVR_val_008981.png',
#  'CLEVR_val_013931.png',
#  'CLEVR_val_014857.png',
#  'CLEVR_val_000048.png',
#  'CLEVR_val_006878.png',
#  'CLEVR_val_000063.png',
#  'CLEVR_val_003481.png',
#  'CLEVR_val_013004.png',
#  'CLEVR_val_007865.png',
#  'CLEVR_val_002001.png',
#  'CLEVR_val_014858.png',
#  'CLEVR_val_000064.png',
#  'CLEVR_val_000951.png',
#  'CLEVR_val_003390.png',
#  'CLEVR_val_013721.png',
#  'CLEVR_val_013153.png',
#  'CLEVR_val_008208.png',
#  'CLEVR_val_012989.png',
#  'CLEVR_val_006118.png',
#  'CLEVR_val_003502.png',
#  'CLEVR_val_013319.png',
#  'CLEVR_val_008135.png',
#  'CLEVR_val_006216.png',
#  'CLEVR_val_007890.png',
#  'CLEVR_val_011424.png',
#  'CLEVR_val_001498.png',
#  'CLEVR_val_005453.png',
#  'CLEVR_val_005542.png',
#  'CLEVR_val_005883.png',
#  'CLEVR_val_014471.png',
#  'CLEVR_val_006992.png',
#  'CLEVR_val_008266.png',
#  'CLEVR_val_005847.png',
#  'CLEVR_val_009305.png',
#  'CLEVR_val_003108.png',
#  'CLEVR_val_006123.png',
#  'CLEVR_val_012008.png',
#  'CLEVR_val_013697.png',
#  'CLEVR_val_008235.png',
#  'CLEVR_val_007619.png',
#  'CLEVR_val_006641.png',
#  'CLEVR_val_013693.png',
#  'CLEVR_val_014484.png',
#  'CLEVR_val_010039.png',
#  'CLEVR_val_007610.png',
#  'CLEVR_val_008680.png',
#  'CLEVR_val_005577.png',
#  'CLEVR_val_004653.png',
#  'CLEVR_val_013470.png',
#  'CLEVR_val_010858.png',
#  'CLEVR_val_010540.png',
#  'CLEVR_val_008839.png',
#  'CLEVR_val_009502.png',
#  'CLEVR_val_003770.png',
#  'CLEVR_val_011429.png',
#  'CLEVR_val_012352.png',
#  'CLEVR_val_014526.png',
#  'CLEVR_val_000469.png',
#  'CLEVR_val_004384.png',
#  'CLEVR_val_012053.png',
#  'CLEVR_val_014159.png',
#  'CLEVR_val_010060.png',
#  'CLEVR_val_005364.png',
#  'CLEVR_val_009376.png',
#  'CLEVR_val_003056.png',
#  'CLEVR_val_011435.png',
#  'CLEVR_val_008719.png',
#  'CLEVR_val_008318.png',
#  'CLEVR_val_001807.png',
#  'CLEVR_val_009831.png',
#  'CLEVR_val_013435.png',
#  'CLEVR_val_008292.png',
#  'CLEVR_val_001562.png',
#  'CLEVR_val_003205.png',
#  'CLEVR_val_008179.png',
#  'CLEVR_val_007869.png',
#  'CLEVR_val_000946.png',
#  'CLEVR_val_005056.png',
#  'CLEVR_val_003469.png',
#  'CLEVR_val_006055.png',
#  'CLEVR_val_011064.png',
#  'CLEVR_val_011476.png',
#  'CLEVR_val_010805.png',
#  'CLEVR_val_003355.png',
#  'CLEVR_val_011106.png',
#  'CLEVR_val_002611.png',
#  'CLEVR_val_009178.png',
#  'CLEVR_val_004910.png',
#  'CLEVR_val_007963.png',
#  'CLEVR_val_014128.png',
#  'CLEVR_val_000347.png',
#  'CLEVR_val_001688.png',
#  'CLEVR_val_005012.png',
#  'CLEVR_val_004930.png',
#  'CLEVR_val_004604.png',
#  'CLEVR_val_013776.png',
#  'CLEVR_val_003111.png',
#  'CLEVR_val_008499.png',
#  'CLEVR_val_007146.png',
#  'CLEVR_val_000662.png',
#  'CLEVR_val_014815.png',
#  'CLEVR_val_014402.png',
#  'CLEVR_val_004862.png',
#  'CLEVR_val_013174.png',
#  'CLEVR_val_004110.png',
#  'CLEVR_val_014214.png',
#  'CLEVR_val_004711.png',
#  'CLEVR_val_012233.png',
#  'CLEVR_val_006190.png',
#  'CLEVR_val_007831.png',
#  'CLEVR_val_007754.png',
#  'CLEVR_val_006973.png',
#  'CLEVR_val_012315.png',
#  'CLEVR_val_014659.png',
#  'CLEVR_val_008972.png',
#  'CLEVR_val_012519.png',
#  'CLEVR_val_009486.png',
#  'CLEVR_val_002292.png',
#  'CLEVR_val_003989.png',
#  'CLEVR_val_009902.png',
#  'CLEVR_val_007512.png',
#  'CLEVR_val_010548.png',
#  'CLEVR_val_010987.png',
#  'CLEVR_val_008929.png',
#  'CLEVR_val_001827.png',
#  'CLEVR_val_007618.png',
#  'CLEVR_val_014885.png',
#  'CLEVR_val_007652.png',
#  'CLEVR_val_013628.png',
#  'CLEVR_val_011873.png',
#  'CLEVR_val_012168.png',
#  'CLEVR_val_013086.png',
#  'CLEVR_val_007689.png',
#  'CLEVR_val_012673.png',
#  'CLEVR_val_012098.png',
#  'CLEVR_val_009574.png',
#  'CLEVR_val_001381.png',
#  'CLEVR_val_008188.png',
#  'CLEVR_val_013014.png',
#  'CLEVR_val_009008.png',
#  'CLEVR_val_003351.png',
#  'CLEVR_val_002626.png',
#  'CLEVR_val_014723.png',
#  'CLEVR_val_003217.png',
#  'CLEVR_val_006659.png',
#  'CLEVR_val_013762.png',
#  'CLEVR_val_004417.png',
#  'CLEVR_val_003564.png',
#  'CLEVR_val_006432.png',
#  'CLEVR_val_011736.png',
#  'CLEVR_val_003476.png',
#  'CLEVR_val_000364.png',
#  'CLEVR_val_003505.png',
#  'CLEVR_val_002111.png',
#  'CLEVR_val_012741.png',
#  'CLEVR_val_005352.png',
#  'CLEVR_val_006517.png',
#  'CLEVR_val_004039.png',
#  'CLEVR_val_006091.png',
#  'CLEVR_val_009041.png',
#  'CLEVR_val_007644.png',
#  'CLEVR_val_011819.png',
#  'CLEVR_val_009842.png',
#  'CLEVR_val_001319.png',
#  'CLEVR_val_008207.png',
#  'CLEVR_val_011280.png',
#  'CLEVR_val_007524.png',
#  'CLEVR_val_004689.png',
#  'CLEVR_val_011976.png',
#  'CLEVR_val_007953.png',
#  'CLEVR_val_001324.png',
#  'CLEVR_val_005949.png',
#  'CLEVR_val_002716.png',
#  'CLEVR_val_003777.png',
#  'CLEVR_val_005827.png',
#  'CLEVR_val_007235.png',
#  'CLEVR_val_010991.png',
#  'CLEVR_val_001403.png',
#  'CLEVR_val_010725.png',
#  'CLEVR_val_014731.png',
#  'CLEVR_val_010927.png',
#  'CLEVR_val_004203.png',
#  'CLEVR_val_005550.png',
#  'CLEVR_val_011666.png',
#  'CLEVR_val_003550.png',
#  'CLEVR_val_009663.png',
#  'CLEVR_val_010452.png',
#  'CLEVR_val_012508.png',
#  'CLEVR_val_013780.png',
#  'CLEVR_val_014372.png',
#  'CLEVR_val_011475.png',
#  'CLEVR_val_012815.png',
#  'CLEVR_val_007358.png',
#  'CLEVR_val_001011.png',
#  'CLEVR_val_005853.png',
#  'CLEVR_val_002992.png',
#  'CLEVR_val_007110.png',
#  'CLEVR_val_014308.png',
#  'CLEVR_val_014309.png',
#  'CLEVR_val_006462.png',
#  'CLEVR_val_014275.png',
#  'CLEVR_val_006901.png',
#  'CLEVR_val_014510.png',
#  'CLEVR_val_003086.png',
#  'CLEVR_val_014952.png',
#  'CLEVR_val_001937.png',
#  'CLEVR_val_014206.png',
#  'CLEVR_val_007126.png',
#  'CLEVR_val_001272.png',
#  'CLEVR_val_005088.png',
#  'CLEVR_val_008827.png',
#  'CLEVR_val_006380.png',
#  'CLEVR_val_008572.png',
#  'CLEVR_val_007094.png',
#  'CLEVR_val_010934.png',
#  'CLEVR_val_001619.png',
#  'CLEVR_val_011975.png',
#  'CLEVR_val_004198.png',
#  'CLEVR_val_012772.png',
#  'CLEVR_val_009451.png',
#  'CLEVR_val_008901.png',
#  'CLEVR_val_013304.png',
#  'CLEVR_val_004415.png',
#  'CLEVR_val_005693.png',
#  'CLEVR_val_005394.png',
#  'CLEVR_val_006142.png',
#  'CLEVR_val_013723.png',
#  'CLEVR_val_005811.png',
#  'CLEVR_val_009964.png',
#  'CLEVR_val_004607.png',
#  'CLEVR_val_014481.png',
#  'CLEVR_val_007595.png',
#  'CLEVR_val_000206.png',
#  'CLEVR_val_007851.png',
#  'CLEVR_val_010701.png',
#  'CLEVR_val_005621.png',
#  'CLEVR_val_001419.png',
#  'CLEVR_val_003238.png',
#  'CLEVR_val_011418.png',
#  'CLEVR_val_011307.png',
#  'CLEVR_val_008100.png',
#  'CLEVR_val_012572.png',
#  'CLEVR_val_000899.png',
#  'CLEVR_val_002207.png',
#  'CLEVR_val_004681.png',
#  'CLEVR_val_013378.png',
#  'CLEVR_val_006410.png',
#  'CLEVR_val_009780.png',
#  'CLEVR_val_012589.png',
#  'CLEVR_val_002924.png',
#  'CLEVR_val_007694.png',
#  'CLEVR_val_011071.png',
#  'CLEVR_val_013825.png',
#  'CLEVR_val_007763.png',
#  'CLEVR_val_004618.png',
#  'CLEVR_val_014901.png',
#  'CLEVR_val_011332.png',
#  'CLEVR_val_012441.png',
#  'CLEVR_val_004230.png',
#  'CLEVR_val_011835.png',
#  'CLEVR_val_000803.png',
#  'CLEVR_val_012533.png',
#  'CLEVR_val_004383.png',
#  'CLEVR_val_001555.png',
#  'CLEVR_val_002871.png',
#  'CLEVR_val_014829.png',
#  'CLEVR_val_005637.png',
#  'CLEVR_val_011338.png',
#  'CLEVR_val_010774.png',
#  'CLEVR_val_009729.png',
#  'CLEVR_val_010748.png',
#  'CLEVR_val_013830.png',
#  'CLEVR_val_013847.png',
#  'CLEVR_val_004613.png',
#  'CLEVR_val_014589.png',
#  'CLEVR_val_006139.png',
#  'CLEVR_val_009025.png',
#  'CLEVR_val_004090.png',
#  'CLEVR_val_006257.png',
#  'CLEVR_val_004731.png',
#  'CLEVR_val_009950.png',
#  'CLEVR_val_007660.png',
#  'CLEVR_val_008184.png',
#  'CLEVR_val_005903.png',
#  'CLEVR_val_000279.png',
#  'CLEVR_val_004087.png',
#  'CLEVR_val_012353.png',
#  'CLEVR_val_004645.png',
#  'CLEVR_val_005154.png',
#  'CLEVR_val_010214.png',
#  'CLEVR_val_011118.png',
#  'CLEVR_val_012578.png',
#  'CLEVR_val_013129.png',
#  'CLEVR_val_011555.png',
#  'CLEVR_val_007112.png',
#  'CLEVR_val_009968.png',
#  'CLEVR_val_007311.png',
#  'CLEVR_val_014868.png',
#  'CLEVR_val_008365.png',
#  'CLEVR_val_001958.png',
#  'CLEVR_val_000291.png',
#  'CLEVR_val_008540.png',
#  'CLEVR_val_007986.png',
#  'CLEVR_val_014971.png',
#  'CLEVR_val_014923.png',
#  'CLEVR_val_011046.png',
#  'CLEVR_val_010234.png',
#  'CLEVR_val_007204.png',
#  'CLEVR_val_008538.png',
#  'CLEVR_val_006704.png',
#  'CLEVR_val_008395.png',
#  'CLEVR_val_004557.png',
#  'CLEVR_val_008988.png',
#  'CLEVR_val_013468.png',
#  'CLEVR_val_006537.png',
#  'CLEVR_val_002101.png',
#  'CLEVR_val_012654.png',
#  'CLEVR_val_006484.png',
#  'CLEVR_val_003716.png',
#  'CLEVR_val_009841.png',
#  'CLEVR_val_007017.png',
#  'CLEVR_val_010040.png',
#  'CLEVR_val_002902.png',
#  'CLEVR_val_009395.png',
#  'CLEVR_val_002358.png',
#  'CLEVR_val_008113.png',
#  'CLEVR_val_002724.png',
#  'CLEVR_val_002159.png',
#  'CLEVR_val_007940.png',
#  'CLEVR_val_008515.png',
#  'CLEVR_val_006559.png',
#  'CLEVR_val_004580.png',
#  'CLEVR_val_012349.png',
#  'CLEVR_val_010130.png',
#  'CLEVR_val_006735.png',
#  'CLEVR_val_007286.png',
#  'CLEVR_val_003045.png',
#  'CLEVR_val_004404.png',
#  'CLEVR_val_004843.png',
#  'CLEVR_val_012011.png',
#  'CLEVR_val_012460.png',
#  'CLEVR_val_004709.png',
#  'CLEVR_val_003311.png',
#  'CLEVR_val_010646.png',
#  'CLEVR_val_012252.png',
#  'CLEVR_val_001290.png',
#  'CLEVR_val_008578.png',
#  'CLEVR_val_009284.png',
#  'CLEVR_val_014748.png',
#  'CLEVR_val_008729.png',
#  'CLEVR_val_004733.png',
#  'CLEVR_val_005070.png',
#  'CLEVR_val_009825.png',
#  'CLEVR_val_001081.png',
#  'CLEVR_val_009102.png',
#  'CLEVR_val_007565.png',
#  'CLEVR_val_004981.png',
#  'CLEVR_val_008136.png',
#  'CLEVR_val_003025.png',
#  'CLEVR_val_005434.png',
#  'CLEVR_val_012069.png',
#  'CLEVR_val_006435.png',
#  'CLEVR_val_000325.png',
#  'CLEVR_val_008486.png',
#  'CLEVR_val_008245.png',
#  'CLEVR_val_014624.png',
#  'CLEVR_val_006009.png',
#  'CLEVR_val_003815.png',
#  'CLEVR_val_013456.png',
#  'CLEVR_val_002587.png',
#  'CLEVR_val_014025.png',
#  'CLEVR_val_007592.png',
#  'CLEVR_val_009166.png',
#  'CLEVR_val_005438.png',
#  'CLEVR_val_002722.png',
#  'CLEVR_val_006144.png',
#  'CLEVR_val_005869.png',
#  'CLEVR_val_008891.png',
#  'CLEVR_val_010309.png',
#  'CLEVR_val_001687.png',
#  'CLEVR_val_006519.png',
#  'CLEVR_val_013066.png',
#  'CLEVR_val_014899.png',
#  'CLEVR_val_001131.png',
#  'CLEVR_val_011283.png',
#  'CLEVR_val_005015.png',
#  'CLEVR_val_008857.png',
#  'CLEVR_val_010584.png',
#  'CLEVR_val_012577.png',
#  'CLEVR_val_000082.png',
#  'CLEVR_val_002875.png',
#  'CLEVR_val_009045.png',
#  'CLEVR_val_006336.png',
#  'CLEVR_val_012567.png',
#  'CLEVR_val_011559.png',
#  'CLEVR_val_003123.png',
#  'CLEVR_val_009925.png',
#  'CLEVR_val_010127.png',
#  'CLEVR_val_004921.png',
#  'CLEVR_val_000033.png',
#  'CLEVR_val_010513.png',
#  'CLEVR_val_006918.png',
#  'CLEVR_val_013841.png',
#  'CLEVR_val_006861.png',
#  'CLEVR_val_001971.png',
#  'CLEVR_val_002579.png',
#  'CLEVR_val_013568.png',
#  'CLEVR_val_000632.png',
#  'CLEVR_val_009013.png',
#  'CLEVR_val_007274.png',
#  'CLEVR_val_008501.png',
#  'CLEVR_val_002806.png',
#  'CLEVR_val_002538.png',
#  'CLEVR_val_005675.png',
#  'CLEVR_val_012389.png',
#  'CLEVR_val_001861.png',
#  'CLEVR_val_011383.png',
#  'CLEVR_val_010265.png',
#  'CLEVR_val_000853.png',
#  'CLEVR_val_001536.png',
#  'CLEVR_val_003866.png',
#  'CLEVR_val_014445.png',
#  'CLEVR_val_006533.png',
#  'CLEVR_val_013900.png',
#  'CLEVR_val_003538.png',
#  'CLEVR_val_000198.png',
#  'CLEVR_val_009207.png',
#  'CLEVR_val_003004.png',
#  'CLEVR_val_007425.png',
#  'CLEVR_val_007612.png',
#  'CLEVR_val_010000.png',
#  'CLEVR_val_002555.png',
#  'CLEVR_val_012903.png',
#  'CLEVR_val_011611.png',
#  'CLEVR_val_001545.png',
#  'CLEVR_val_003665.png',
#  'CLEVR_val_001753.png',
#  'CLEVR_val_014805.png',
#  'CLEVR_val_010552.png',
#  'CLEVR_val_001067.png',
#  'CLEVR_val_008072.png',
#  'CLEVR_val_014955.png',
#  'CLEVR_val_009694.png',
#  'CLEVR_val_014296.png',
#  'CLEVR_val_003522.png',
#  'CLEVR_val_004106.png',
#  'CLEVR_val_009047.png',
#  'CLEVR_val_014645.png',
#  'CLEVR_val_010207.png',
#  'CLEVR_val_000414.png',
#  'CLEVR_val_002969.png',
#  'CLEVR_val_014974.png',
#  'CLEVR_val_009079.png',
#  'CLEVR_val_007213.png',
#  'CLEVR_val_010041.png',
#  'CLEVR_val_009847.png',
#  'CLEVR_val_004741.png',
#  'CLEVR_val_010250.png',
#  'CLEVR_val_006765.png',
#  'CLEVR_val_001558.png',
#  'CLEVR_val_010010.png',
#  'CLEVR_val_011812.png',
#  'CLEVR_val_004644.png',
#  'CLEVR_val_012202.png',
#  'CLEVR_val_012245.png',
#  'CLEVR_val_001127.png',
#  'CLEVR_val_012483.png',
#  'CLEVR_val_006011.png',
#  'CLEVR_val_013415.png',
#  'CLEVR_val_005797.png',
#  'CLEVR_val_010065.png',
#  'CLEVR_val_011203.png',
#  'CLEVR_val_011300.png',
#  'CLEVR_val_011028.png',
#  'CLEVR_val_006063.png',
#  'CLEVR_val_006594.png',
#  'CLEVR_val_012962.png',
#  'CLEVR_val_013947.png',
#  'CLEVR_val_008664.png',
#  'CLEVR_val_001890.png',
#  'CLEVR_val_005095.png',
#  'CLEVR_val_012633.png',
#  'CLEVR_val_010346.png',
#  'CLEVR_val_009253.png',
#  'CLEVR_val_005609.png',
#  'CLEVR_val_001035.png',
#  'CLEVR_val_002917.png',
#  'CLEVR_val_001842.png',
#  'CLEVR_val_007549.png',
#  'CLEVR_val_013275.png',
#  'CLEVR_val_001611.png',
#  'CLEVR_val_011149.png',
#  'CLEVR_val_006807.png',
#  'CLEVR_val_006752.png',
#  'CLEVR_val_011201.png',
#  'CLEVR_val_009673.png',
#  'CLEVR_val_001089.png',
#  'CLEVR_val_003542.png',
#  'CLEVR_val_004962.png',
#  'CLEVR_val_012364.png',
#  'CLEVR_val_001973.png',
#  'CLEVR_val_003264.png',
#  'CLEVR_val_012938.png',
#  'CLEVR_val_010988.png',
#  'CLEVR_val_006855.png',
#  'CLEVR_val_008640.png',
#  'CLEVR_val_005493.png',
#  'CLEVR_val_000709.png',
#  'CLEVR_val_008658.png',
#  'CLEVR_val_010859.png',
#  'CLEVR_val_010168.png',
#  'CLEVR_val_009869.png',
#  'CLEVR_val_011377.png',
#  'CLEVR_val_003147.png',
#  'CLEVR_val_007932.png',
#  'CLEVR_val_006885.png',
#  'CLEVR_val_014595.png',
#  'CLEVR_val_010019.png',
#  'CLEVR_val_013914.png',
#  'CLEVR_val_004007.png',
#  'CLEVR_val_000675.png',
#  'CLEVR_val_008345.png',
#  'CLEVR_val_009998.png',
#  'CLEVR_val_000306.png',
#  'CLEVR_val_008044.png',
#  'CLEVR_val_004956.png',
#  'CLEVR_val_009801.png',
#  'CLEVR_val_004175.png',
#  'CLEVR_val_004577.png',
#  'CLEVR_val_005807.png',
#  'CLEVR_val_003418.png',
#  'CLEVR_val_003656.png',
#  'CLEVR_val_013844.png',
#  'CLEVR_val_011600.png',
#  'CLEVR_val_008033.png',
#  'CLEVR_val_007474.png',
#  'CLEVR_val_001797.png',
#  'CLEVR_val_006400.png',
#  'CLEVR_val_007216.png',
#  'CLEVR_val_000151.png',
#  'CLEVR_val_006786.png',
#  'CLEVR_val_001988.png',
#  'CLEVR_val_013279.png',
#  'CLEVR_val_005062.png',
#  'CLEVR_val_012117.png',
#  'CLEVR_val_006289.png',
#  'CLEVR_val_012279.png',
#  'CLEVR_val_012190.png',
#  'CLEVR_val_005074.png',
#  'CLEVR_val_004057.png',
#  'CLEVR_val_006427.png',
#  'CLEVR_val_008546.png',
#  'CLEVR_val_011985.png',
#  'CLEVR_val_013698.png',
#  'CLEVR_val_011654.png',
#  'CLEVR_val_012423.png',
#  'CLEVR_val_003517.png',
#  'CLEVR_val_001322.png',
#  'CLEVR_val_004548.png',
#  'CLEVR_val_002354.png',
#  'CLEVR_val_011420.png',
#  'CLEVR_val_010474.png',
#  'CLEVR_val_012719.png',
#  'CLEVR_val_013514.png',
#  'CLEVR_val_014964.png',
#  'CLEVR_val_008094.png',
#  'CLEVR_val_000702.png',
#  'CLEVR_val_006769.png',
#  'CLEVR_val_010898.png',
#  'CLEVR_val_001685.png',
#  'CLEVR_val_007366.png',
#  'CLEVR_val_011816.png',
#  'CLEVR_val_011673.png',
#  'CLEVR_val_000232.png',
#  'CLEVR_val_013896.png',
#  'CLEVR_val_001757.png',
#  'CLEVR_val_005038.png',
#  'CLEVR_val_006258.png',
#  'CLEVR_val_002699.png',
#  'CLEVR_val_002743.png',
#  'CLEVR_val_011719.png',
#  'CLEVR_val_004583.png',
#  'CLEVR_val_007622.png',
#  'CLEVR_val_001388.png',
#  'CLEVR_val_011687.png',
#  'CLEVR_val_011810.png',
#  'CLEVR_val_008475.png',
#  'CLEVR_val_002147.png',
#  'CLEVR_val_005653.png',
#  'CLEVR_val_002052.png',
#  'CLEVR_val_013725.png',
#  'CLEVR_val_009036.png',
#  'CLEVR_val_002537.png',
#  'CLEVR_val_002189.png',
#  'CLEVR_val_000969.png',
#  'CLEVR_val_000856.png',
#  'CLEVR_val_005218.png',
#  'CLEVR_val_008860.png',
#  'CLEVR_val_013310.png',
#  'CLEVR_val_001285.png',
#  'CLEVR_val_008513.png',
#  'CLEVR_val_013716.png',
#  'CLEVR_val_005910.png',
#  'CLEVR_val_013137.png',
#  'CLEVR_val_009635.png',
#  'CLEVR_val_000038.png',
#  'CLEVR_val_012321.png',
#  'CLEVR_val_000173.png',
#  'CLEVR_val_014997.png',
#  'CLEVR_val_014409.png',
#  'CLEVR_val_011091.png',
#  'CLEVR_val_008763.png',
#  'CLEVR_val_006755.png',
#  'CLEVR_val_005789.png',
#  'CLEVR_val_009670.png',
#  'CLEVR_val_002723.png',
#  'CLEVR_val_008726.png',
#  'CLEVR_val_014333.png',
#  'CLEVR_val_011013.png',
#  'CLEVR_val_003135.png',
#  'CLEVR_val_007721.png',
#  'CLEVR_val_014091.png',
#  'CLEVR_val_013165.png',
#  'CLEVR_val_012486.png',
#  'CLEVR_val_005042.png',
#  'CLEVR_val_005068.png',
#  'CLEVR_val_007176.png',
#  'CLEVR_val_005365.png',
#  'CLEVR_val_011200.png',
#  'CLEVR_val_008006.png',
#  'CLEVR_val_011416.png',
#  'CLEVR_val_012990.png',
#  'CLEVR_val_013485.png',
#  'CLEVR_val_006960.png',
#  'CLEVR_val_007998.png',
#  'CLEVR_val_004456.png',
#  'CLEVR_val_014249.png',
#  'CLEVR_val_008488.png',
#  'CLEVR_val_006577.png',
#  'CLEVR_val_013089.png',
#  'CLEVR_val_004905.png',
#  'CLEVR_val_007427.png',
#  'CLEVR_val_002422.png',
#  'CLEVR_val_008169.png',
#  'CLEVR_val_003268.png',
#  'CLEVR_val_012634.png',
#  'CLEVR_val_000854.png',
#  'CLEVR_val_011037.png',
#  'CLEVR_val_007413.png',
#  'CLEVR_val_014434.png',
#  'CLEVR_val_000644.png',
#  'CLEVR_val_001484.png',
#  'CLEVR_val_008834.png',
#  'CLEVR_val_000547.png',
#  'CLEVR_val_010024.png',
#  'CLEVR_val_006535.png',
#  'CLEVR_val_007478.png',
#  'CLEVR_val_010510.png',
#  'CLEVR_val_000123.png',
#  'CLEVR_val_005412.png',
#  'CLEVR_val_011671.png',
#  'CLEVR_val_012124.png',
#  'CLEVR_val_000020.png',
#  'CLEVR_val_002662.png',
#  'CLEVR_val_001911.png',
#  'CLEVR_val_014710.png',
#  'CLEVR_val_012416.png',
#  'CLEVR_val_014797.png',
#  'CLEVR_val_002584.png',
#  'CLEVR_val_003535.png',
#  'CLEVR_val_011603.png',
#  'CLEVR_val_012972.png',
#  'CLEVR_val_009092.png',
#  'CLEVR_val_014555.png',
#  'CLEVR_val_000550.png',
#  'CLEVR_val_003149.png',
#  'CLEVR_val_014138.png',
#  'CLEVR_val_000730.png',
#  'CLEVR_val_006034.png',
#  'CLEVR_val_004917.png',
#  'CLEVR_val_006816.png',
#  'CLEVR_val_009696.png',
#  'CLEVR_val_010393.png',
#  'CLEVR_val_010889.png',
#  'CLEVR_val_001981.png',
#  'CLEVR_val_002341.png',
#  'CLEVR_val_014007.png',
#  'CLEVR_val_000276.png',
#  'CLEVR_val_010673.png',
#  'CLEVR_val_004569.png',
#  'CLEVR_val_002559.png',
#  'CLEVR_val_009748.png',
#  'CLEVR_val_008450.png',
#  'CLEVR_val_004422.png',
#  'CLEVR_val_000001.png',
#  'CLEVR_val_005676.png',
#  'CLEVR_val_000339.png',
#  ...]

# %%
#image = skimage.io.imread(os.path.join(IMAGE_DIR, random.choice(file_names)))
#image = skimage.io.imread(os.path.join(IMAGE_DIR, file_names[3]))
image = skimage.io.imread(os.path.join(IMAGE_DIR, file_names[32]))
image = image[:,:,:3]

# %%
plt.imshow(image)

# %%
# Run detection
results = model.detect([image], verbose=1)
# Out:
# Processing 1 images
# image                    shape: (320, 480, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 109)              min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
# Visualize results
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])

# %%
r['rois'][0]
# Out:
# array([ 86, 118, 186, 204], dtype=int32)

# %%
plt.imshow(image)

# %%
r['rois'][0]
# Out:
# array([110, 134, 233, 237], dtype=int32)

# %%
y1, x1, y2, x2 = r['rois'][0]

# %%
y1
# Out:
# 110

# %%
(x1, y1), x2 - x1, y2 - y1,
# Out:
# ((134, 110), 103, 123)

# %%
class_names[84]
# Out:
# 'cylinder metal blue large'
